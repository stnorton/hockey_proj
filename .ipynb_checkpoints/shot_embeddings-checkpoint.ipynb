# %%
#imports
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Activation, concatenate, Dense, Dropout, Embedding, Input, Reshape, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.text import Tokenizer
import os

os.chdir('C:/Users/Sean/Documents/Projects/hockey_proj')
pd.options.display.max_columns = None
# Out:
# WARNING:tensorflow:From C:\Users\Sean\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
#read in data from csv
all_df = pd.read_csv('all_events23.csv')
# Out:
# C:\Users\Sean\AppData\Local\Temp\ipykernel_9388\109595414.py:2: DtypeWarning: Columns (51,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_df = pd.read_csv('all_events23.csv')

# %%
#check out data
all_df.shape
all_df.event_type.unique()
# Out:
# array(['GAME_SCHEDULED', 'FACEOFF', 'HIT', 'SHOT', 'STOP', 'MISSED_SHOT',
#        'GIVEAWAY', 'BLOCKED_SHOT', 'GOAL', 'TAKEAWAY', 'PENALTY',
#        'PERIOD_END', 'GAME_END', 'CHALLENGE', 'SHOOTOUT_COMPLETE',
#        'UNKNOWN', 'FAILED_SHOT_ATTEMPT', 'EARLY_INT_START',
#        'EARLY_INT_END'], dtype=object)

# %%
#we want to keep shots on net and goals
shots_df = all_df[all_df.event_type.isin(['SHOT', 'GOAL'])]
shots_df.head()
# Out:
#     Unnamed: 0   X        xg      event_id event_type event secondary_type  \
# 4            5   5  0.025524  2.022020e+13       SHOT  Shot     Wrist Shot
# 11          12  12  0.063270  2.022020e+13       SHOT  Shot      Slap Shot
# 12          13  13  0.451566  2.022020e+13       GOAL  Goal     Wrist Shot
# 14          15  15  0.054611  2.022020e+13       SHOT  Shot     Wrist Shot
# 22          23  23  0.151387  2.022020e+13       SHOT  Shot         Tip-In
#
#              event_team event_team_type  \
# 4       San Jose Sharks            away
# 11  Nashville Predators            home
# 12  Nashville Predators            home
# 14  Nashville Predators            home
# 22      San Jose Sharks            away
#
#                                           description  period  period_seconds  \
# 4          Timo Meier Wrist Shot saved by Juuse Saros       1              23
# 11     Mattias Ekholm Slap Shot saved by James Reimer       1              59
# 12  Kiefer Sherwood (1) Wrist Shot, assists: Matti...       1              61
# 14    Colton Sissons Wrist Shot saved by James Reimer       1              72
# 22         Steven Lorentz Tip-In saved by Juuse Saros       1             162
#
#     period_seconds_remaining  game_seconds  game_seconds_remaining  \
# 4                       1177            23                    3577
# 11                      1141            59                    3541
# 12                      1139            61                    3539
# 14                      1128            72                    3528
# 22                      1038           162                    3438
#
#     home_score  away_score event_player_1_name event_player_1_type  \
# 4            0           0          Timo.Meier             Shooter
# 11           0           0      Mattias.Ekholm             Shooter
# 12           1           0     Kiefer.Sherwood              Scorer
# 14           1           0      Colton.Sissons             Shooter
# 22           1           0      Steven.Lorentz             Shooter
#
#    event_player_2_name event_player_2_type event_player_3_name  \
# 4          Juuse.Saros              Goalie                 NaN
# 11        James.Reimer              Goalie                 NaN
# 12      Mattias.Ekholm              Assist       Ryan.McDonagh
# 14        James.Reimer              Goalie                 NaN
# 22         Juuse.Saros              Goalie                 NaN
#
#    event_player_3_type event_goalie_name strength_state strength_code  \
# 4                  NaN       Juuse.Saros            5v5            EV
# 11                 NaN      James.Reimer            5v5            EV
# 12              Assist      James.Reimer            5v5            EV
# 14                 NaN      James.Reimer            5v5            EV
# 22                 NaN       Juuse.Saros            5v5            EV
#
#    strength game_winning_goal empty_net penalty_severity  penalty_minutes  \
# 4      Even               NaN       NaN              NaN              NaN
# 11     Even               NaN       NaN              NaN              NaN
# 12     Even             False     False              NaN              NaN
# 14     Even               NaN       NaN              NaN              NaN
# 22     Even               NaN       NaN              NaN              NaN
#
#     event_idx  num_on  players_on  num_off  players_off extra_attacker     x  \
# 4           6     NaN         NaN      NaN          NaN          False  44.0
# 11         15     NaN         NaN      NaN          NaN          False -33.0
# 12         16     NaN         NaN      NaN          NaN          False -74.0
# 14         20     NaN         NaN      NaN          NaN          False -81.0
# 22         32     NaN         NaN      NaN          NaN          False  72.0
#
#        y  x_fixed  y_fixed  shot_distance  shot_angle  home_skaters  \
# 4    8.0    -44.0     -8.0           45.7        10.1             5
# 11   8.0     33.0     -8.0           56.6         8.1             5
# 12  -5.0     74.0      5.0           15.8        18.4             5
# 14  15.0     81.0    -15.0           17.0        61.9             5
# 22   2.0    -72.0     -2.0           17.1         6.7             5
#
#     away_skaters          home_on_1        home_on_2          home_on_3  \
# 4              5     Filip.Forsberg  Mikael.Granlund       Matt.Duchene
# 11             5  Nino.Niederreiter    Ryan.McDonagh    Kiefer.Sherwood
# 12             5  Nino.Niederreiter    Ryan.McDonagh    Kiefer.Sherwood
# 14             5       Yakov.Trenin   Colton.Sissons       Dante.Fabbro
# 22             5         Cole.Smith       Roman.Josi  Alexandre.Carrier
#
#          home_on_4          home_on_5 home_on_6 home_on_7         away_on_1  \
# 4       Roman.Josi  Alexandre.Carrier       NaN       NaN  Scott.Harrington
# 11  Mattias.Ekholm      Ryan.Johansen       NaN       NaN     Logan.Couture
# 12  Mattias.Ekholm      Ryan.Johansen       NaN       NaN     Logan.Couture
# 14  Tanner.Jeannot    Mark.Borowiecki       NaN       NaN       Radim.Simek
# 22   Eeli.Tolvanen         Cody.Glass       NaN       NaN    Steven.Lorentz
#
#            away_on_2      away_on_3            away_on_4       away_on_5  \
# 4         Timo.Meier  Erik.Karlsson           Luke.Kunin     Tomas.Hertl
# 11     Mario.Ferraro   Kevin.Labanc  Marc.Edouard.Vlasic  Oskar.Lindblom
# 12     Mario.Ferraro   Kevin.Labanc  Marc.Edouard.Vlasic  Oskar.Lindblom
# 14       Nick.Bonino   Matt.Benning           Matt.Nieto     Noah.Gregor
# 22  Scott.Harrington     Nico.Sturm      Jonah.Gadjovich   Erik.Karlsson
#
#    away_on_6 away_on_7  home_goalie   away_goalie     game_id  \
# 4        NaN       NaN  Juuse.Saros  James.Reimer  2022020001
# 11       NaN       NaN  Juuse.Saros  James.Reimer  2022020001
# 12       NaN       NaN  Juuse.Saros  James.Reimer  2022020001
# 14       NaN       NaN  Juuse.Saros  James.Reimer  2022020001
# 22       NaN       NaN  Juuse.Saros  James.Reimer  2022020001
#
#     event_player_1_id     event_player_1_link  event_player_1_season_total  \
# 4           8478414.0  /api/v1/people/8478414                          NaN
# 11          8475218.0  /api/v1/people/8475218                          NaN
# 12          8480748.0  /api/v1/people/8480748                          1.0
# 14          8476925.0  /api/v1/people/8476925                          NaN
# 22          8478904.0  /api/v1/people/8478904                          NaN
#
#     event_player_2_id     event_player_2_link  event_player_2_season_total  \
# 4           8477424.0  /api/v1/people/8477424                          NaN
# 11          8473503.0  /api/v1/people/8473503                          NaN
# 12          8475218.0  /api/v1/people/8475218                          1.0
# 14          8473503.0  /api/v1/people/8473503                          NaN
# 22          8477424.0  /api/v1/people/8477424                          NaN
#
#     event_player_3_id     event_player_3_link  event_player_3_season_total  \
# 4                 NaN                     NaN                          NaN
# 11                NaN                     NaN                          NaN
# 12          8474151.0  /api/v1/people/8474151                          1.0
# 14                NaN                     NaN                          NaN
# 22                NaN                     NaN                          NaN
#
#     event_player_4_id event_player_4_name     event_player_4_link  \
# 4                 NaN                 NaN                     NaN
# 11                NaN                 NaN                     NaN
# 12          8473503.0        James Reimer  /api/v1/people/8473503
# 14                NaN                 NaN                     NaN
# 22                NaN                 NaN                     NaN
#
#    event_player_4_type period_type ordinal_num period_time  \
# 4                  NaN     REGULAR         1st       00:23
# 11                 NaN     REGULAR         1st       00:59
# 12              Goalie     REGULAR         1st       01:01
# 14                 NaN     REGULAR         1st       01:12
# 22                 NaN     REGULAR         1st       02:42
#
#    period_time_remaining             date_time  event_team_id  \
# 4                  19:37  2022-10-07T18:06:53Z           28.0
# 11                 19:01  2022-10-07T18:07:29Z           18.0
# 12                 18:59  2022-10-07T18:07:31Z           18.0
# 14                 18:48  2022-10-07T18:07:42Z           18.0
# 22                 17:18  2022-10-07T18:09:12Z           28.0
#
#      event_team_link event_team_abbr  home_final  away_final  event_goalie_id  \
# 4   /api/v1/teams/28             SJS         4.0         1.0        8477424.0
# 11  /api/v1/teams/18             NSH         4.0         1.0        8473503.0
# 12  /api/v1/teams/18             NSH         4.0         1.0        8473503.0
# 14  /api/v1/teams/18             NSH         4.0         1.0        8473503.0
# 22  /api/v1/teams/28             SJS         4.0         1.0        8477424.0
#
#          event_goalie_link event_goalie_type  ids_on  ids_off      season  \
# 4   /api/v1/people/8477424            Goalie     NaN      NaN  20222023.0
# 11  /api/v1/people/8473503            Goalie     NaN      NaN  20222023.0
# 12  /api/v1/people/8473503            Goalie     NaN      NaN  20222023.0
# 14  /api/v1/people/8473503            Goalie     NaN      NaN  20222023.0
# 22  /api/v1/people/8477424            Goalie     NaN      NaN  20222023.0
#
#    season_type   game_date           game_start             game_end  \
# 4            R  2022-10-07  2022-10-07 14:00:00  2022-10-07 16:49:33
# 11           R  2022-10-07  2022-10-07 14:00:00  2022-10-07 16:49:33
# 12           R  2022-10-07  2022-10-07 14:00:00  2022-10-07 16:49:33
# 14           R  2022-10-07  2022-10-07 14:00:00  2022-10-07 16:49:33
# 22           R  2022-10-07  2022-10-07 14:00:00  2022-10-07 16:49:33
#
#    game_length game_state detailed_state         venue_name  \
# 4   2H 49M 33S      Final          Final  O2 Czech Republic
# 11  2H 49M 33S      Final          Final  O2 Czech Republic
# 12  2H 49M 33S      Final          Final  O2 Czech Republic
# 14  2H 49M 33S      Final          Final  O2 Czech Republic
# 22  2H 49M 33S      Final          Final  O2 Czech Republic
#
#              venue_link            home_name home_abbreviation  \
# 4   /api/v1/venues/null  Nashville Predators               NSH
# 11  /api/v1/venues/null  Nashville Predators               NSH
# 12  /api/v1/venues/null  Nashville Predators               NSH
# 14  /api/v1/venues/null  Nashville Predators               NSH
# 22  /api/v1/venues/null  Nashville Predators               NSH
#
#    home_division_name home_division_name_short home_conference_name  home_id  \
# 4             Central                      CEN              Western     18.0
# 11            Central                      CEN              Western     18.0
# 12            Central                      CEN              Western     18.0
# 14            Central                      CEN              Western     18.0
# 22            Central                      CEN              Western     18.0
#
#           away_name away_abbreviation away_division_name  \
# 4   San Jose Sharks               SJS            Pacific
# 11  San Jose Sharks               SJS            Pacific
# 12  San Jose Sharks               SJS            Pacific
# 14  San Jose Sharks               SJS            Pacific
# 22  San Jose Sharks               SJS            Pacific
#
#    away_division_name_short away_conference_name  away_id  venue_id
# 4                       PAC              Western     28.0       NaN
# 11                      PAC              Western     28.0       NaN
# 12                      PAC              Western     28.0       NaN
# 14                      PAC              Western     28.0       NaN
# 22                      PAC              Western     28.0       NaN

# %%
#keep only useful columns 
shots_df = shots_df[['event_type', 'secondary_type', 'event_player_1_name', 'strength_code', 'x_fixed', 'y_fixed', 'shot_distance', 'shot_angle']]
shots_df.head()
# Out:
#    event_type secondary_type event_player_1_name strength_code  x_fixed  \
# 4        SHOT     Wrist Shot          Timo.Meier            EV    -44.0
# 11       SHOT      Slap Shot      Mattias.Ekholm            EV     33.0
# 12       GOAL     Wrist Shot     Kiefer.Sherwood            EV     74.0
# 14       SHOT     Wrist Shot      Colton.Sissons            EV     81.0
# 22       SHOT         Tip-In      Steven.Lorentz            EV    -72.0
#
#     y_fixed  shot_distance  shot_angle
# 4      -8.0           45.7        10.1
# 11     -8.0           56.6         8.1
# 12      5.0           15.8        18.4
# 14    -15.0           17.0        61.9
# 22     -2.0           17.1         6.7

# %%
#rename column and generate unique player_ids
shots_df = shots_df.rename(columns={'event_player_1_name': 'name'})
shots_df['pid'] = pd.factorize(shots_df['name'])[0]

# %%
#get key mapping pids to names
#get name index pairs from shots_df
unique_pairs = shots_df.drop_duplicates(subset=['name', 'pid'])
player_pid_mapping = unique_pairs.groupby('name')['pid'].unique().reset_index()
player_pid_mapping = pd.DataFrame(player_pid_mapping)
#convert pid to int
player_pid_mapping['pid'] = player_pid_mapping['pid'].astype(int)

# %%
#get dummies for shot type and strength_code
shots_df = pd.get_dummies(shots_df, columns = ['secondary_type', 'strength_code'], dtype=int)

# %%
#create goal_variable
shots_df['goal'] = np.where(shots_df['event_type'] == 'GOAL', 1, 0)

# %%
shots_df.head()
# Out:
#    event_type             name  x_fixed  y_fixed  shot_distance  shot_angle  \
# 4        SHOT       Timo.Meier    -44.0     -8.0           45.7        10.1
# 11       SHOT   Mattias.Ekholm     33.0     -8.0           56.6         8.1
# 12       GOAL  Kiefer.Sherwood     74.0      5.0           15.8        18.4
# 14       SHOT   Colton.Sissons     81.0    -15.0           17.0        61.9
# 22       SHOT   Steven.Lorentz    -72.0     -2.0           17.1         6.7
#
#     pid  secondary_type_Backhand  secondary_type_Batted  \
# 4     0                        0                      0
# 11    1                        0                      0
# 12    2                        0                      0
# 14    3                        0                      0
# 22    4                        0                      0
#
#     secondary_type_Between Legs  secondary_type_Cradle  \
# 4                             0                      0
# 11                            0                      0
# 12                            0                      0
# 14                            0                      0
# 22                            0                      0
#
#     secondary_type_Deflected  secondary_type_Penalty Shot  \
# 4                          0                            0
# 11                         0                            0
# 12                         0                            0
# 14                         0                            0
# 22                         0                            0
#
#     secondary_type_Poke  secondary_type_Slap Shot  secondary_type_Snap Shot  \
# 4                     0                         0                         0
# 11                    0                         1                         0
# 12                    0                         0                         0
# 14                    0                         0                         0
# 22                    0                         0                         0
#
#     secondary_type_Tip-In  secondary_type_Wrap-around  \
# 4                       0                           0
# 11                      0                           0
# 12                      0                           0
# 14                      0                           0
# 22                      1                           0
#
#     secondary_type_Wrist Shot  strength_code_EV  strength_code_PP  \
# 4                           1                 1                 0
# 11                          0                 1                 0
# 12                          1                 1                 0
# 14                          1                 1                 0
# 22                          0                 1                 0
#
#     strength_code_SH  goal
# 4                  0     0
# 11                 0     0
# 12                 0     1
# 14                 0     0
# 22                 0     0

# %%
#scale numeric data to 0/1
scaler = MinMaxScaler()
num_cols = ['x_fixed', 'y_fixed', 'shot_distance', 'shot_angle']
shots_df[num_cols] = scaler.fit_transform(shots_df[num_cols])

# %%
#convert player ids to a string 
shots_df.pid = shots_df.pid.astype('str')

# %%
#set up and run tokenizer
shooter_tokenizer = Tokenizer()

shooter_tokenizer.fit_on_texts(shots_df.pid)

# %%
#convert to sequences to feed neural net - all sequences are same length, no padding
shooters = shooter_tokenizer.texts_to_sequences(shots_df.pid)
shooters = [x[0] for x in shooters]
shooters = np.array(shooters)

# %%
#set target for fitting embeddings - goals
goal = np.array(shots_df.goal)
shot_info = shots_df.drop(columns=['pid', 'goal', 'name', 'event_type'], axis=1, inplace=False)
SHOT_COLS = shot_info.shape[1]
NUM_SHOOTERS = len(np.unique(shooters)) + 2
VEC_SIZE = 50

# %%
# the input layers
shooter_input = Input(shape=(1, ), name="shooter_input")
shot_input = Input(shape=(SHOT_COLS, ), name="shot_input")

# shooter layers
s1 = Embedding(NUM_SHOOTERS, VEC_SIZE, input_length=1)(shooter_input)
s2 = Flatten()(s1)
s3 = Dense(1, activation="sigmoid")(s2)

# shot layers
s4 = Dense(16, activation='relu')(shot_input)
s5 = Dense(8, activation='relu')(s4)

# concatenate both paths
concatenated = concatenate([s3, s5])

# output layer
output = Dense(1, activation='sigmoid')(concatenated)

# create model
model = Model(inputs=[shooter_input, shot_input], outputs=output)
# Out:
# WARNING:tensorflow:From C:\Users\Sean\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  shooter_input (InputLayer)  [(None, 1)]                  0         []
#
#  embedding (Embedding)       (None, 1, 50)                43850     ['shooter_input[0][0]']
#
#  shot_input (InputLayer)     [(None, 19)]                 0         []
#
#  flatten (Flatten)           (None, 50)                   0         ['embedding[0][0]']
#
#  dense_1 (Dense)             (None, 16)                   320       ['shot_input[0][0]']
#
#  dense (Dense)               (None, 1)                    51        ['flatten[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    136       ['dense_1[0][0]']
#
#  concatenate (Concatenate)   (None, 9)                    0         ['dense[0][0]',
#                                                                      'dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    10        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 44367 (173.31 KB)
# Trainable params: 44367 (173.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#compile model
model.compile(optimizer="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Sean\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
X = [shooters, shot_info]
history = model.fit(X, goal, epochs=10)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Sean\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Sean\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2025/2025 [==============================] - 4s 1ms/step - loss: 0.3240 - accuracy: 0.8955
# Epoch 2/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2998 - accuracy: 0.8982
# Epoch 3/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2958 - accuracy: 0.8981
# Epoch 4/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2941 - accuracy: 0.8980
# Epoch 5/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2929 - accuracy: 0.8981
# Epoch 6/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2919 - accuracy: 0.8981
# Epoch 7/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2912 - accuracy: 0.8981
# Epoch 8/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2908 - accuracy: 0.8982
# Epoch 9/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2902 - accuracy: 0.8982
# Epoch 10/10
# 2025/2025 [==============================] - 2s 1ms/step - loss: 0.2900 - accuracy: 0.8983

# %%
#get embeddings
embedding_layer = model.get_layer('embedding')
shooter_embeddings = embedding_layer.get_weights()[0]

# %%
print(shooter_embeddings)
# Out:
# [[-0.01292566  0.01885775  0.03231278 ... -0.01065129  0.01371595
#    0.02087052]
#  [-0.12677248 -0.10376463 -0.2074242  ... -0.21960841  0.13908523
#   -0.11912046]
#  [-0.0138919   0.0235996   0.00757613 ... -0.01674541  0.03078135
#    0.01970288]
#  ...
#  [ 0.28168747  0.22151344  0.2592446  ...  0.26335078 -0.29089874
#    0.2123611 ]
#  [ 0.10703351  0.07058522  0.00976349 ...  0.04867141 -0.09336188
#    0.00929139]
#  [-0.0014543  -0.0056044   0.02833753 ... -0.04613603  0.0205858
#    0.01210567]]

# %%
# make the embed vectors a pandas dataframe
shooter_embeddings = pd.DataFrame(shooter_embeddings)
shooter_embeddings.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.022192  0.011245 -0.032531  0.049329 -0.029744  0.009000 -0.044930
# 1  0.152841 -0.235352 -0.208972 -0.229480  0.152205 -0.138292 -0.160937
# 2  0.177515 -0.198818 -0.192883 -0.189295  0.221831 -0.202387 -0.143346
# 3 -0.051684  0.045323  0.026551  0.084307 -0.011685  0.098770  0.035624
# 4 -0.049619  0.045235  0.058379  0.051550 -0.057101  0.077846  0.023243
#
#          7         8         9         10        11        12        13  \
# 0 -0.035952  0.048024 -0.032446  0.025550  0.038355 -0.014732  0.005475
# 1  0.168056 -0.141138  0.221545  0.202763  0.177171 -0.161440 -0.208070
# 2  0.142166 -0.218605  0.222986  0.154694  0.165252 -0.175187 -0.179465
# 3 -0.088679  0.047632 -0.103323 -0.065182 -0.017486  0.100778  0.112023
# 4 -0.081356  0.045606 -0.067361  0.001763  0.002096  0.086398  0.013075
#
#          14        15        16        17        18        19        20  \
# 0  0.037555 -0.036123  0.013865  0.007276 -0.019852  0.021447  0.018596
# 1  0.145056 -0.243878  0.216302 -0.188928 -0.243610  0.160543  0.156964
# 2  0.230013 -0.202168  0.154499 -0.219805 -0.212487  0.179024  0.193361
# 3 -0.020218  0.067689 -0.027486  0.059353  0.026200 -0.031356 -0.046602
# 4 -0.020535  0.039203 -0.084504  0.044779  0.003284 -0.045027 -0.067333
#
#          21        22        23        24        25        26        27  \
# 0 -0.044796  0.023798 -0.046145 -0.004973  0.016015 -0.043422 -0.006767
# 1 -0.151005  0.167247  0.202051  0.210489  0.135924 -0.172658 -0.191543
# 2 -0.130645  0.194108  0.192925  0.162755  0.216818 -0.185495 -0.225264
# 3  0.031782 -0.019731 -0.064642 -0.021312 -0.083652  0.046627  0.072482
# 4 -0.009035 -0.067773 -0.062386  0.011005 -0.062871  0.018533  0.057700
#
#          28        29        30        31        32        33        34  \
# 0  0.025994 -0.043547 -0.019669 -0.045132  0.043915 -0.016018 -0.047103
# 1 -0.185757 -0.179759 -0.198636  0.130101  0.181310 -0.107068 -0.221785
# 2 -0.200317 -0.204387 -0.240080  0.187986  0.230157 -0.113080 -0.153287
# 3  0.050249  0.062772  0.060120 -0.021497 -0.039408  0.059343  0.102907
# 4  0.066586  0.050256  0.032216 -0.047002 -0.011253  0.051189  0.024332
#
#          35        36        37        38        39        40        41  \
# 0  0.032766  0.006411  0.009212  0.047163  0.030987  0.030015  0.030788
# 1  0.133545  0.231786 -0.226405 -0.148754  0.163326 -0.136656 -0.169800
# 2  0.162664  0.225009 -0.137750 -0.150475  0.190466 -0.142317 -0.153234
# 3 -0.086575 -0.080573  0.100881  0.080254 -0.106813  0.039124  0.030498
# 4 -0.029509 -0.053771  0.085987 -0.004906 -0.021085  0.022138 -0.001723
#
#          42        43        44        45        46        47        48  \
# 0  0.006251 -0.012393  0.046111  0.012055  0.024149 -0.020427 -0.045764
# 1 -0.210699  0.169203 -0.083975 -0.150257 -0.158707  0.224356  0.198516
# 2 -0.211302  0.104903 -0.163166 -0.185760 -0.188961  0.205577  0.162633
# 3  0.054966 -0.048235  0.027666  0.095903  0.093906 -0.065509 -0.031822
# 4  0.032484 -0.032023  0.030106  0.060863 -0.002142 -0.036177 -0.008199
#
#          49
# 0 -0.046511
# 1 -0.221775
# 2 -0.236461
# 3  0.006457
# 4  0.042043

# %%
# a list of true shooter ids
shooter_id = {k:v for k, v in shooter_tokenizer.index_word.items()}
shooter_df = pd.DataFrame.from_dict(shooter_id, orient='index', columns=["playerid"])

# %%
# Out:
#          e1        e2        e3
# 1 -0.126772 -0.103765 -0.207424
# 2 -0.013892  0.023600  0.007576
# 3 -0.059690 -0.032343 -0.107803

# %%
# name the columns
shooter_embeddings.columns = ["e" + str(i + 1) for i in range(shooter_embeddings.shape[1])]

# align the data by index
shooter_embeddings = pd.merge(shooter_embeddings, shooter_df, how='inner', left_index=True, right_index=True)

# %%
# clean up the index so its the player
shooter_embeddings.index = shooter_embeddings.playerid

# the first few
shooter_embeddings.iloc[:3, :3]
# Out:
#                 e1        e2        e3
# playerid
# 96        0.152841 -0.235352 -0.208972
# 239       0.177515 -0.198818 -0.192883
# 179      -0.051684  0.045323  0.026551

# %%
#rename column
shooter_embeddings = shooter_embeddings.rename(columns = {'playerid':'pid'})

# %%
#export to 3d space
from sklearn.manifold import TSNE
shooter_tsne = TSNE(n_components=3).fit_transform(shooter_embeddings.iloc[:, :50])

# %%
shooter_embeddings.reset_index(drop=True, inplace=True)

# %%
# Out:
#                 e1        e2        e3        e4        e5        e6  \
# playerid
# 96        0.152841 -0.235352 -0.208972 -0.229480  0.152205 -0.138292
# 239       0.177515 -0.198818 -0.192883 -0.189295  0.221831 -0.202387
# 179      -0.051684  0.045323  0.026551  0.084307 -0.011685  0.098770
# 302      -0.049619  0.045235  0.058379  0.051550 -0.057101  0.077846
# 0        -0.073702  0.032564 -0.013251  0.040774 -0.025088  0.041930
#
#                 e7        e8        e9       e10       e11       e12  \
# playerid
# 96       -0.160937  0.168056 -0.141138  0.221545  0.202763  0.177171
# 239      -0.143346  0.142166 -0.218605  0.222986  0.154694  0.165252
# 179       0.035624 -0.088679  0.047632 -0.103323 -0.065182 -0.017486
# 302       0.023243 -0.081356  0.045606 -0.067361  0.001763  0.002096
# 0         0.050511 -0.027606  0.037461 -0.006210  0.004907 -0.027966
#
#                e13       e14       e15       e16       e17       e18  \
# playerid
# 96       -0.161440 -0.208070  0.145056 -0.243878  0.216302 -0.188928
# 239      -0.175187 -0.179465  0.230013 -0.202168  0.154499 -0.219805
# 179       0.100778  0.112023 -0.020218  0.067689 -0.027486  0.059353
# 302       0.086398  0.013075 -0.020535  0.039203 -0.084504  0.044779
# 0         0.029291  0.021868  0.007239  0.015117 -0.058583  0.033997
#
#                e19       e20       e21       e22       e23       e24  \
# playerid
# 96       -0.243610  0.160543  0.156964 -0.151005  0.167247  0.202051
# 239      -0.212487  0.179024  0.193361 -0.130645  0.194108  0.192925
# 179       0.026200 -0.031356 -0.046602  0.031782 -0.019731 -0.064642
# 302       0.003284 -0.045027 -0.067333 -0.009035 -0.067773 -0.062386
# 0         0.010608 -0.063622  0.005722  0.009801  0.025829 -0.019528
#
#                e25       e26       e27       e28       e29       e30  \
# playerid
# 96        0.210489  0.135924 -0.172658 -0.191543 -0.185757 -0.179759
# 239       0.162755  0.216818 -0.185495 -0.225264 -0.200317 -0.204387
# 179      -0.021312 -0.083652  0.046627  0.072482  0.050249  0.062772
# 302       0.011005 -0.062871  0.018533  0.057700  0.066586  0.050256
# 0        -0.065273 -0.048533  0.057404  0.038707  0.018894  0.060713
#
#                e31       e32       e33       e34       e35       e36  \
# playerid
# 96       -0.198636  0.130101  0.181310 -0.107068 -0.221785  0.133545
# 239      -0.240080  0.187986  0.230157 -0.113080 -0.153287  0.162664
# 179       0.060120 -0.021497 -0.039408  0.059343  0.102907 -0.086575
# 302       0.032216 -0.047002 -0.011253  0.051189  0.024332 -0.029509
# 0         0.023861 -0.103749 -0.001826  0.086265  0.010682 -0.041484
#
#                e37       e38       e39       e40       e41       e42  \
# playerid
# 96        0.231786 -0.226405 -0.148754  0.163326 -0.136656 -0.169800
# 239       0.225009 -0.137750 -0.150475  0.190466 -0.142317 -0.153234
# 179      -0.080573  0.100881  0.080254 -0.106813  0.039124  0.030498
# 302      -0.053771  0.085987 -0.004906 -0.021085  0.022138 -0.001723
# 0        -0.023250  0.045459 -0.001510  0.006322 -0.015940  0.048930
#
#                e43       e44       e45       e46       e47       e48  \
# playerid
# 96       -0.210699  0.169203 -0.083975 -0.150257 -0.158707  0.224356
# 239      -0.211302  0.104903 -0.163166 -0.185760 -0.188961  0.205577
# 179       0.054966 -0.048235  0.027666  0.095903  0.093906 -0.065509
# 302       0.032484 -0.032023  0.030106  0.060863 -0.002142 -0.036177
# 0         0.040362 -0.013443  0.050593  0.037688  0.015798 -0.040677
#
#                e49       e50 playerid
# playerid
# 96        0.198516 -0.221775       96
# 239       0.162633 -0.236461      239
# 179      -0.031822  0.006457      179
# 302      -0.008199  0.042043      302
# 0         0.021905  0.006668        0

# %%
#merge back in player_names and ids
shooter_tsne = pd.DataFrame(shooter_tsne)
shooter_tsne['pid'] = shooter_embeddings['pid']
shooter_tsne['pid'] = shooter_tsne['pid'].astype(int)

# %%
shooter_embeddings.shape
# Out:
# (875, 51)

# %%
#merge in names
shooter_tsne_named = pd.merge(shooter_tsne, player_pid_mapping, on='pid')

# %%
shooter_embeddings['pid'] = shooter_embeddings.pid.astype(int)
shooter_embeddings = pd.merge(shooter_embeddings, player_pid_mapping, on='pid')

# %%
#write out to csv
shooter_tsne_named.to_csv('shooter_embed_3d.csv')
shooter_embeddings.to_csv('shooter_embed_full.csv')
